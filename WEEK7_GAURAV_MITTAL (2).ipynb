# %%
# Install required libraries
# !pip -q install -U \
langchain \
langchain-community \
langchain-google-genai \
langchain-text-splitters \
pypdf \
faiss-cpu \
sentence-transformers

# %%
import os

from google.colab import files

from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

from langchain_google_genai import ChatGoogleGenerativeAI

# %%
import os
import getpass

os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter API Key: ")
# Out:
# Enter API Key: ··········

# %%
uploaded = files.upload()

pdf_path = list(uploaded.keys())[0]

print("Uploaded:", pdf_path)
# Out:
#      <input type="file" id="files-c5c383dd-be32-48d5-acab-0c9ef6e82396" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c5c383dd-be32-48d5-acab-0c9ef6e82396">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
loader = PyPDFLoader(pdf_path)

documents = loader.load()

print("Total Pages:", len(documents))
# Out:
# Total Pages: 22

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_documents(documents)

print("Total Chunks:", len(chunks))
# Out:
# Total Chunks: 73

# %%
embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
vectorstore = FAISS.from_documents(
    documents=chunks,
    embedding=embedding_model
)

print("Vector Database Created Successfully!")
# Out:
# Vector Database Created Successfully!

# %%
retriever = vectorstore.as_retriever(
    search_kwargs={"k":3}
)

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.3
)

# %%
question = input("Ask a Question: ")

retrieved_docs = retriever.invoke(question)

context = "\n\n".join(
    doc.page_content
    for doc in retrieved_docs
)
# Out:
# Ask a Question: give summary and some questions

# %%
prompt = f"""
You are a helpful AI assistant.

Answer ONLY from the provided context.

If the answer is not available,
say:

"I couldn't find this information in the document."

Context:

{context}

Question:

{question}

Answer:
"""

response = llm.invoke(prompt)

print(response.content)
# Out:
# I couldn't find this information in the document.

# %% [markdown]
# ![Screenshot 2026-07-06 043015.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-07-06 043028.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-07-06 043038.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-07-06 043049.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-07-06 043057.png](data:image/png;base64,...)
